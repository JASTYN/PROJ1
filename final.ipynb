# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("saber_combined_all_fields.csv")

# %%
df.describe()
# Out:
#           Unnamed: 0        periodo  estu_cod_reside_depto  \
# count  212010.000000  212010.000000          211645.000000
# mean   106004.500000   20170.184156              37.972761
# std     61202.159623      14.162938             947.511332
# min         0.000000   20123.000000               5.000000
# 25%     53002.250000   20163.000000              11.000000
# 50%    106004.500000   20173.000000              13.000000
# 75%    159006.750000   20183.000000              52.000000
# max    212009.000000   20184.000000           99999.000000
#
#        estu_cod_reside_mcpio  estu_ano_examenestado_sb11  estu_semestrecursa  \
# count          211645.000000                46960.000000        126187.00000
# mean            29130.862539                 2011.922466             6.94940
# std             25780.276662                    2.210888             2.68588
# min              5001.000000                 1968.000000             1.00000
# ...

# %%
df.head(6)
# Out:
#    Unnamed: 0 estu_tipodocumento estu_nacionalidad estu_genero  \
# 0           0                 TI          COLOMBIA           M
# 1           1                 CC          COLOMBIA           M
# 2           2                 CC          COLOMBIA           F
# 3           3                 TI          COLOMBIA           F
# 4           4                 CC          COLOMBIA           M
# 5           5                 CC          COLOMBIA           M
#
#   estu_fechanacimiento estu_exterior  periodo estu_consecutivo  \
# 0           30/07/1996           NaN    20134   EK201340233804
# 1           13/04/1994           NaN    20133   EK201330220754
# 2           08/12/1991           NaN    20134   EK201340246502
# 3           10/01/1996           NaN    20134   EK201340237996
# 4           11/10/1995            NO    20173   EK201730119521
# 5           08/08/1995            NO    20173   EK201730081262
#
#   estu_estadocivil estu_estudiante  ... punt_biologia punt_quimica  \
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0        periodo  estu_cod_reside_depto  \
# count  212010.000000  212010.000000          211645.000000
# mean   106004.500000   20170.184156              37.972761
# std     61202.159623      14.162938             947.511332
# min         0.000000   20123.000000               5.000000
# 25%     53002.250000   20163.000000              11.000000
# 50%    106004.500000   20173.000000              13.000000
# 75%    159006.750000   20183.000000              52.000000
# max    212009.000000   20184.000000           99999.000000
#
#        estu_cod_reside_mcpio  estu_ano_examenestado_sb11  estu_semestrecursa  \
# count          211645.000000                46960.000000        126187.00000
# mean            29130.862539                 2011.922466             6.94940
# std             25780.276662                    2.210888             2.68588
# min              5001.000000                 1968.000000             1.00000
# ...

# %%
pd.set_option('display.max_rows',10)

print(df)
# Out:
#         Unnamed: 0 estu_tipodocumento estu_nacionalidad estu_genero  \
# 0                0                 TI          COLOMBIA           M
# 1                1                 CC          COLOMBIA           M
# 2                2                 CC          COLOMBIA           F
# 3                3                 TI          COLOMBIA           F
# 4                4                 CC          COLOMBIA           M
# ...            ...                ...               ...         ...
# 212005      212005                 CC          COLOMBIA           F
# 212006      212006                 CC          COLOMBIA           F
# 212007      212007                 CC          COLOMBIA           F
# 212008      212008                 CC          COLOMBIA           M
# 212009      212009                 CC          COLOMBIA           M
#
#        estu_fechanacimiento estu_exterior  periodo estu_consecutivo  \
# 0                30/07/1996           NaN    20134   EK201340233804
# ...

# %%
df1=df.columns

# %%
df1
# Out:
# Index(['Unnamed: 0', 'estu_tipodocumento', 'estu_nacionalidad', 'estu_genero',
#        'estu_fechanacimiento', 'estu_exterior', 'periodo', 'estu_consecutivo',
#        'estu_estadocivil', 'estu_estudiante',
#        ...
#        'punt_biologia', 'punt_quimica', 'punt_fisica',
#        'punt_ciencias_sociales', 'punt_filosofia', 'punt_ingles',
#        'desemp_ingles', 'profundiza', 'puntaje_prof', 'desemp_prof'],
#       dtype='object', length=144)

# %%
df.shape
# Out:
# (212010, 144)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of         Unnamed: 0 estu_tipodocumento estu_nacionalidad estu_genero  \
# 0                0                 TI          COLOMBIA           M
# 1                1                 CC          COLOMBIA           M
# 2                2                 CC          COLOMBIA           F
# 3                3                 TI          COLOMBIA           F
# 4                4                 CC          COLOMBIA           M
# ...            ...                ...               ...         ...
# 212005      212005                 CC          COLOMBIA           F
# 212006      212006                 CC          COLOMBIA           F
# 212007      212007                 CC          COLOMBIA           F
# 212008      212008                 CC          COLOMBIA           M
# 212009      212009                 CC          COLOMBIA           M
#
#        estu_fechanacimiento estu_exterior  periodo estu_consecutivo  \
# ...

# %%
cols = df.select_dtypes([np.number]).columns

# %%
cols
# Out:
# Index(['Unnamed: 0', 'periodo', 'estu_cod_reside_depto',
#        'estu_cod_reside_mcpio', 'estu_ano_examenestado_sb11',
#        'estu_semestrecursa', 'inst_cod_institucion',
#        'estu_snies_prgmacademico', 'estu_prgm_codmunicipio',
#        'estu_inst_codmunicipio', 'mod_razona_cuantitat_punt',
#        'mod_lectura_critica_punt', 'mod_competen_ciudada_punt',
#        'mod_ingles_punt', 'mod_comuni_escrita_punt',
#        'estu_inst_cod_departamento', 'periodo.1', 'estu_cod_reside_depto.1',
#        'estu_cod_reside_mcpio.1', 'cole_codigo_icfes',
#        'cole_cod_dane_establecimiento', 'cole_cod_dane_sede',
#        'cole_cod_mcpio_ubicacion', 'cole_cod_depto_ubicacion', 'punt_lenguaje',
#        'punt_matematicas', 'punt_biologia', 'punt_quimica', 'punt_fisica',
#        'punt_ciencias_sociales', 'punt_filosofia', 'punt_ingles',
#        'puntaje_prof'],
#       dtype='object')

# %%
dfnew = df.select_dtypes(include=np.number)

# %%
dfnew
# Out:
#         Unnamed: 0  periodo  estu_cod_reside_depto  estu_cod_reside_mcpio  \
# 0                0    20134                   15.0                15322.0
# 1                1    20133                   91.0                91001.0
# 2                2    20134                   66.0                66170.0
# 3                3    20134                   13.0                13001.0
# 4                4    20173                   25.0                25754.0
# ...            ...      ...                    ...                    ...
# 212005      212005    20183                   23.0                23855.0
# 212006      212006    20183                   11.0                11001.0
# 212007      212007    20183                   19.0                19212.0
# 212008      212008    20183                   50.0                50001.0
# 212009      212009    20183                   76.0                76001.0
#
#         estu_ano_examenestado_sb11  estu_semestrecursa  inst_cod_institucion  \
# ...

# %%
dfwork=dfnew.fillna(dfnew.mean(), inplace=True)
# count the number of NaN values in each column
print(dfwork)
# Out:
# None

# %%
dfnew
# Out:
#         Unnamed: 0  periodo  estu_cod_reside_depto  estu_cod_reside_mcpio  \
# 0                0    20134                   15.0                15322.0
# 1                1    20133                   91.0                91001.0
# 2                2    20134                   66.0                66170.0
# 3                3    20134                   13.0                13001.0
# 4                4    20173                   25.0                25754.0
# ...            ...      ...                    ...                    ...
# 212005      212005    20183                   23.0                23855.0
# 212006      212006    20183                   11.0                11001.0
# 212007      212007    20183                   19.0                19212.0
# 212008      212008    20183                   50.0                50001.0
# 212009      212009    20183                   76.0                76001.0
#
#         estu_ano_examenestado_sb11  estu_semestrecursa  inst_cod_institucion  \
# ...

# %%
dfnew.isna().any()
# Out:
# Unnamed: 0                    False
# periodo                       False
# estu_cod_reside_depto         False
# estu_cod_reside_mcpio         False
# estu_ano_examenestado_sb11    False
#                               ...
# punt_fisica                   False
# punt_ciencias_sociales        False
# punt_filosofia                False
# punt_ingles                   False
# puntaje_prof                  False
# Length: 33, dtype: bool

# %%
df.corr
# Out:
# <bound method DataFrame.corr of         Unnamed: 0 estu_tipodocumento estu_nacionalidad estu_genero  \
# 0                0                 TI          COLOMBIA           M
# 1                1                 CC          COLOMBIA           M
# 2                2                 CC          COLOMBIA           F
# 3                3                 TI          COLOMBIA           F
# 4                4                 CC          COLOMBIA           M
# ...            ...                ...               ...         ...
# 212005      212005                 CC          COLOMBIA           F
# 212006      212006                 CC          COLOMBIA           F
# 212007      212007                 CC          COLOMBIA           F
# 212008      212008                 CC          COLOMBIA           M
# 212009      212009                 CC          COLOMBIA           M
#
#        estu_fechanacimiento estu_exterior  periodo estu_consecutivo  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'estu_tipodocumento', 'estu_nacionalidad', 'estu_genero',
#        'estu_fechanacimiento', 'estu_exterior', 'periodo', 'estu_consecutivo',
#        'estu_estadocivil', 'estu_estudiante',
#        ...
#        'punt_biologia', 'punt_quimica', 'punt_fisica',
#        'punt_ciencias_sociales', 'punt_filosofia', 'punt_ingles',
#        'desemp_ingles', 'profundiza', 'puntaje_prof', 'desemp_prof'],
#       dtype='object', length=144)

# %% [markdown]
# # correlation

# %%
df[["puntaje_prof","punt_filosofia"]].corr
# Out:
# <bound method DataFrame.corr of         puntaje_prof  punt_filosofia
# 0               49.0            29.0
# 1                6.0            47.0
# 2                5.0            45.0
# 3               29.0            40.0
# 4               55.0            43.0
# ...              ...             ...
# 212005           6.0            52.0
# 212006           5.0            42.0
# 212007          52.0            34.0
# 212008          52.0            33.0
# 212009           6.0            69.0
#
# [212010 rows x 2 columns]>

# %%
df2=df[["puntaje_prof","punt_filosofia"]].corr

# %%
df2
# Out:
# <bound method DataFrame.corr of         puntaje_prof  punt_filosofia
# 0               49.0            29.0
# 1                6.0            47.0
# 2                5.0            45.0
# 3               29.0            40.0
# 4               55.0            43.0
# ...              ...             ...
# 212005           6.0            52.0
# 212006           5.0            42.0
# 212007          52.0            34.0
# 212008          52.0            33.0
# 212009           6.0            69.0
#
# [212010 rows x 2 columns]>

# %% [markdown]
# # missing values

# %%
df.isna().any()
# Out:
# Unnamed: 0              False
# estu_tipodocumento      False
# estu_nacionalidad       False
# estu_genero              True
# estu_fechanacimiento     True
#                         ...
# punt_ingles             False
# desemp_ingles            True
# profundiza              False
# puntaje_prof            False
# desemp_prof              True
# Length: 144, dtype: bool

# %%
df.isna()
# Out:
#         Unnamed: 0  estu_tipodocumento  estu_nacionalidad  estu_genero  \
# 0            False               False              False        False
# 1            False               False              False        False
# 2            False               False              False        False
# 3            False               False              False        False
# 4            False               False              False        False
# ...            ...                 ...                ...          ...
# 212005       False               False              False        False
# 212006       False               False              False        False
# 212007       False               False              False        False
# 212008       False               False              False        False
# 212009       False               False              False        False
#
#         estu_fechanacimiento  estu_exterior  periodo  estu_consecutivo  \
# ...

# %%
df4.any
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4092/1724789704.py in <module>
# ----> 1 df4.any
#
# NameError: name 'df4' is not defined

# %% [markdown]
# # treating
# mean
# median

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
imp = SimpleImputer(strategy="most_frequent")
df3=imp.fit_transform(df)

# %%
df3

# %% [markdown]
# # outliers

# %%
df.columns

# %%
df.head(6)

# %%
df.punt_biologia

# %%
df4=df.isna

# %%
df.any

# %%
df5=df.notnull
df5

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("saber_11_pro.csv")
# Out:
# C:\Users\JASTYN\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (46,92,99) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.describe()
# Out:
#            PERIODO_x  ESTU_COD_RESIDE_DEPTO_x  ESTU_COD_RESIDE_MCPIO_x  \
# count  208981.000000            204247.000000            204247.000000
# mean    20125.890488                31.115801             31280.151694
# std         5.165760                26.270253             26299.107698
# min     20121.000000                 5.000000              5001.000000
# 25%     20122.000000                11.000000             11001.000000
# 50%     20122.000000                17.000000             17174.000000
# 75%     20132.000000                54.000000             54001.000000
# max     20141.000000                99.000000             99773.000000
#
#        COLE_CODIGO_ICFES  COLE_COD_DANE_ESTABLECIMIENTO  \
# count      198342.000000                   2.089160e+05
# mean        57247.022194                   2.283810e+11
# std         47102.197875                   1.016395e+11
# min             0.000000                   3.110010e+10
# ...

# %%
df.head(6)
# Out:
#   ESTU_TIPODOCUMENTO_x ESTU_NACIONALIDAD_x ESTU_GENERO_x  \
# 0                   CC            COLOMBIA             M
# 1                   CC            COLOMBIA             M
# 2                   TI            COLOMBIA             M
# 3                   TI            COLOMBIA             M
# 4                   TI            COLOMBIA             M
# 5                   CC            COLOMBIA             F
#
#   ESTU_FECHANACIMIENTO_x  PERIODO_x ESTU_CONSECUTIVO_x ESTU_ESTUDIANTE_x  \
# 0             05/01/1990      20121   SB11201210058388        ESTUDIANTE
# 1             01/08/1993      20121   SB11201210060023        ESTUDIANTE
# 2             27/05/1995      20121   SB11201210060020        ESTUDIANTE
# 3             19/10/1994      20121   SB11201210060017        ESTUDIANTE
# 4             16/07/1993      20121   SB11201210060019        ESTUDIANTE
# 5             10/02/1970      20121   SB11201210039541        ESTUDIANTE
#
# ...

# %%
df1=df.head(8)

# %%
df1.to_excel("jasty.xlsx")

# %%
df3=pd.read_csv("saber_11_pro.csv")
# Out:
# C:\Users\JASTYN\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (46,92,99) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df3.to_excel("change.xlsx")

# %%
df4=pd.read_csv("https://drive.google.com/drive/folders/1uL82iIS7ueScY2uHTLQJvmUrVnj7-NxL")
